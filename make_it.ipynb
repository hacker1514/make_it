# %% [markdown]
# <a href="https://colab.research.google.com/github/hacker1514/make_it/blob/main/make_it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div>
# <img alt="Make IT" src="https://hacker1514.github.io/make_it/main/assets/images/logo.svg" width=100 height=100>
# <div>
# <h1>WELCOME TO MAKE IT</h1>
# <h4>Niranjan Kumar K</h4>

# %% [markdown]
# <h1>Deployment of LLM and Starting Service to it</h1>

# %% [markdown]
# <h3>Note1 : Please Run all cells and copy the output of server.start()['tunnel_url'] .<h3>
# <h3>Note2 : share copied output to make it in terminal</h3>

# %%
# !pip install kshell

# %%
from kshell import *

# %%
#please keep username and password constant
server = Server(username="makeit",password="1234",mode="public")

# %%
try :
  server.start()
except :
  import os
  os.kill(os.getpid(), 9)
# Out:
# ...
#   KSHELL SERVER RUNNING
# ...
# Mode:           PUBLIC
# Local:          localhost:1514
# Public:         https://maine-utils-weekends-warrant.trycloudflare.com
# Authentication: username/password
# Tunnel:         Cloudflare
# Status:         ACTIVE
# ...

# %%
server.status()['tunnel_url']
# Out:
# 'https://maine-utils-weekends-warrant.trycloudflare.com'

# %% [markdown]
# <h3>FInal Note : copy only url of server.status no single qoute or something else</h3>
